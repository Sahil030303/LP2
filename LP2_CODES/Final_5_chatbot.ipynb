# %%
import nltk
from nltk.chat.util import Chat, reflections

pairs = [
    [
        r"hi|hello",
        ["Hello! How can I assist you with your JioMart shopping today?"]
    ],
    [
        r"what can I buy from JioMart?",
        ["JioMart offers a wide range of products including groceries, household items, personal care products, electronics, and more. What are you looking for?"]
    ],
    [
        r"how can I place an order?",
        ["To place an order on JioMart, you can visit our website or mobile app. You can browse products, add them to your cart, and proceed to checkout. If you need assistance, feel free to ask."]
    ],
    [
        r"do you have any ongoing offers?",
        ["Yes, we have several ongoing offers and discounts on various products. Please check our website or app to explore the current deals."]
    ],
    [
        r"how can I track my order?",
        ["Once your order is placed, you will receive a confirmation message with a tracking link. You can click on the link to track the status of your order in real-time."]
    ],
    [
        r"can I return or exchange a product?",
        ["Yes, you can return or exchange a product within a specified time period. Please check our return policy on the website or contact our customer support for further assistance."]
    ],
    [
        r"what are the payment options available?",
        ["We accept multiple payment options including credit cards, debit cards, net banking, and mobile wallets. Cash on delivery is also available in select locations."]
    ],
    [
        r"how can I contact customer support?",
        ["You can reach our customer support team by calling our helpline number or sending an email. Our representatives are available to assist you with any queries or concerns."]
    ],
    [
        r"what are the delivery options?",
        ["We offer both home delivery and in-store pickup options. During checkout, you can choose the most convenient option for you."]
    ],
    [
        r"can I schedule a delivery?",
        ["Yes, you can schedule your delivery as per your preferred date and time during the checkout process."]
    ],
    [
        r"are there any membership programs?",
        ["Yes, we have a membership program called JioMart Plus. It offers various benefits like free delivery, exclusive discounts, and priority access to new launches."]
    ],
    [
        r"how can I sign up for JioMart Plus?",
        ["To sign up for JioMart Plus, you can visit our website or app and follow the instructions to subscribe. Membership details and benefits will be provided during the signup process."]
    ],
    [
        r"do you have a mobile app?",
        ["Yes, we have a mobile app available for both Android and iOS devices. You can download it from the respective app stores."]
    ],
    [
        r"can I track my previous orders?",
        ["Yes, you can view your order history and track previous orders by logging into your JioMart account on our website or app."]
    ],
    [
        r"how can I provide feedback or suggestions?",
        ["We value your feedback! You can provide feedback or suggestions through our website or app. Alternatively, you can contact our customer support team."]
    ],
    [
        r"are there any bulk purchase discounts?",
        ["Yes, we offer bulk purchase discounts on select products. Please check the product details or contact our customer support for more information."]
    ],
    [
        r"do you have a loyalty program?",
        ["Yes, we have a loyalty program that rewards you for your purchases. You can earn points and redeem them for discounts or other benefits."]
    ],
    [
        r"what are the customer support hours?",
        ["Our customer support is available 24/7 to assist you. You can reach out to us anytime with your queries."]
    ],
    [
        r"how can I unsubscribe from JioMart Plus?",
        ["To unsubscribe from JioMart Plus, please contact our customer support team. They will assist you with the cancellation process."]
    ],
    [
        r"tell me more about JioMart",
        ["JioMart is an online grocery and retail platform that offers a wide range of products at competitive prices. It is backed by reliable delivery and convenient payment options."]
    ],
    [
        r"do you have a referral program?",
        ["Yes, we have a referral program where you can refer your friends and earn rewards. Check our website or app for more details."]
    ],
    [
        r"how can I update my account information?",
        ["You can update your account information by logging into your JioMart account on our website or app. There, you can edit your profile and manage your details."]
    ],
    [
        r"thank you|thanks",
        ["You're welcome! If you have any more questions, feel free to ask. Happy shopping with JioMart!"]
    ],
    [
        r"quit",
        ["Thank you for chatting with JioMart. Have a great day!"]
    ]
]

def func():
    ch = Chat(pairs)
    ch.converse()

if __name__== "__main__":
    func()
# Out:
# >how can I update my account information?
# You can update your account information by logging into your JioMart account on our website or app. There, you can edit your profile and manage your details.
# >quit
# Thank you for chatting with JioMart. Have a great day!

# %%
import nltk
from nltk.chat.util import Chat, reflections

pairs = [
    [
        r"hi|hello",
        ["Hello! How can I assist you with your RedBus booking today?"]
    ],
    [
        r"what can I do on RedBus?",
        ["RedBus is a platform for booking bus tickets online. You can search for bus routes, check bus schedules, compare fares, and make bookings. How can I help you?"]
    ],
    [
        r"how can I book a bus ticket?",
        ["To book a bus ticket on RedBus, you can visit our website or use our mobile app. Enter your source and destination cities, select your preferred date, and browse available bus options. Then, proceed to make your booking."]
    ],
    [
        r"do you have any ongoing offers?",
        ["Yes, we have several ongoing offers and discounts on bus bookings. Please check our website or app to explore the current deals."]
    ],
    [
        r"how can I cancel my bus ticket?",
        ["To cancel a bus ticket booked on RedBus, you can visit the 'My Bookings' section on our website or app. Select the booking you wish to cancel and follow the cancellation process. Please note that cancellation charges may apply."]
    ],
    [
        r"can I reschedule my bus ticket?",
        ["Yes, you can reschedule your bus ticket depending on the availability of rescheduling options for your particular booking. Please visit the 'My Bookings' section on our website or app for more information."]
    ],
    [
        r"how can I track my bus?",
        ["If the bus operator provides live tracking, you will receive a tracking link or SMS with the details. You can click on the link or use the tracking information to monitor the location and status of your bus."]
    ],
    [
        r"what are the payment options available?",
        ["We accept multiple payment options including credit cards, debit cards, net banking, and popular mobile wallets. Cash on delivery is also available in select locations."]
    ],
    [
        r"how can I contact customer support?",
        ["You can reach our customer support team by calling our helpline number or sending an email. Our representatives are available 24/7 to assist you with any queries or concerns."]
    ],
    
     [
        r"are there any discounts for frequent travelers?",
        ["Yes, we have a loyalty program called RedBus Rewards. It offers benefits and discounts for frequent travelers. You can earn reward points on your bookings and redeem them for future discounts."]
    ],
    [
        r"do you provide bus bookings for all cities?",
        ["RedBus provides bus bookings for a wide range of cities and routes. We have a large network of bus operators across various locations. Please enter your source and destination cities to check the availability."]
    ],
    [
        r"can I book a return ticket?",
        ["Yes, you can book both one-way and round-trip tickets on RedBus. During the booking process, you can select the desired option depending on your travel requirements."]
    ],
    [
        r"do you offer travel insurance?",
        ["Yes, we offer optional travel insurance coverage for select bookings. You can choose to add travel insurance during the booking process for added peace of mind."]
    ],
    [
        r"how can I provide feedback or suggestions?",
        ["We appreciate your feedback! You can provide feedback or suggestions through our website or app. We value your input to enhance our services."]
    ],
    [
        r"can I book bus tickets for a group?",
        ["Yes, you can book bus tickets for a group on RedBus. During the booking process, you can select the number of passengers and specify the group size. Make sure to check the availability of seats for your group size."]
    ],
    [
        r"are there any bus operators with premium services?",
        ["Yes, we have tie-ups with bus operators that provide premium services such as luxury buses, sleeper coaches, and more. You can choose from the available options based on your preferences."]
    ],
    [
        r"how can I update my account information?",
        ["You can update your account information by logging into your RedBus account on our website or app. There, you can edit your profile and manage your details."]
    ],
    [
        r"can I book bus tickets for a specific date in the future?",
        ["Yes, you can book bus tickets for future dates depending on the availability of buses on your preferred date. You can enter the desired date during the booking process."]
    ],
    [
        r"tell me more about RedBus",
        ["RedBus is India's largest online bus ticketing platform. We connect bus travelers with a network of bus operators across the country. Our aim is to provide a seamless booking experience and convenient travel options."]
    ],
    [
        r"do you have a mobile app?",
        ["Yes, we have a mobile app available for both Android and iOS devices. You can download it from the respective app stores to book tickets on the go."]
    ],
    [
        r"can I change the boarding point after booking?",
        ["In some cases, it may be possible to change the boarding point after booking. However, it depends on the specific bus operator and their policies. Please contact our customer support for assistance in such cases."]
    ],
    [
        r"do you offer any customer support during the journey?",
        ["For any queries or assistance during your bus journey, you can contact our customer support team. They will be available to help you with your concerns."]
    ],
    [
        r"what are the bus ticket cancellation charges?",
        ["Cancellation charges may vary depending on the bus operator and the time of cancellation. During the cancellation process, you will be notified about the applicable charges. Please review the cancellation policy before making a booking."]
    ],
    [
        r"thank you|thanks",
        ["You're welcome! If you have any more questions, feel free to ask. Happy journey with RedBus!"]
    ],
    [
        r"quit",
        ["Thank you for using RedBus. Have a great day!"]
    ]
]


def func():
    ch = Chat(pairs)
    ch.converse()

if __name__== "__main__":
    func()
# Out:
# >what are the bus ticket cancellation charges?
# Cancellation charges may vary depending on the bus operator and the time of cancellation. During the cancellation process, you will be notified about the applicable charges. Please review the cancellation policy before making a booking.
# >quit
# Thank you for using RedBus. Have a great day!
